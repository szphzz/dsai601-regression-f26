# %% [markdown]
# # HW 3 Coding Questions - Sophia Chung

# %% [markdown]
# ## Question 1

# %% [markdown]
# ## Question 2

# %% [markdown]
# **(a)**

# %% [markdown]
# **(b)**

# %% [markdown]
# **(c)**

# %% [markdown]
# ## Question 3

# %% [markdown]
# **(a)**

# %% [markdown]
# **(b)**

# %% [markdown]
# **(c)**

# %% [markdown]
# **(d)**

# %% [markdown]
# **(e)**
